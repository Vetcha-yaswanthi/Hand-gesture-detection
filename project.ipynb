# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt
import numpy as np
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
from google.colab import drive
drive.mount('content')
# !ls  ./
# Out:
# Mounted at content
# content  gdrive  sample_data

# %%
# !ls ./content/MyDrive/rough/report.zip
# Out:
# 'blockchain and flutter'
# 'CamScanner 06-25-2020 08.46.14.gdoc'
# 'CamScanner 06-25-2020 08.46.14.pdf'
# 'covid_19_clean_complete - covid_19_clean_complete.csv'
# 'cse(3rd year)'
#  day3.gdoc
#  ggg
# 'Girlscript chapter Bilaspur Webinar Proposal.gdoc'
# 'ml_resources .gdoc'
# 'OM Exam Form Even Sem AY 2020-21.gdoc'
# 'OM Exam Form Even Sem AY 2020-21.pdf'
#  report.zip
#  resume.pdf
#  samsung.txt
# 'spam_ham_dataset.csv - spam_ham_dataset.csv'
#  tree1.png
#  tree2.png
#  tree3.png
#  tree4.png
#  Untitled0.ipynb
# 'Untitled document.gdoc'
# 'Untitled document.pdf'
# 'Untitled folder'
# 'Untitled folder (1)'
# 'Untitled presentation.gslides'
#  vikram_bais.pdf
#  Vikram_Bais_Resume.pdf

# %%
zip_dir = tf.keras.utils.get_file('report.zip', origin="/content/content/MyDrive/rough", extract=True)
# Out:
# Downloading data from ./content/content/MyDrive/rough
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-1d08626a29a0> in <module>()
# ----> 1 zip_dir = tf.keras.utils.get_file('report.zip', origin="./content/content/MyDrive/rough", extract=True)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/data_utils.py in get_file(fname, origin, untar, md5_hash, file_hash, cache_subdir, hash_algorithm, extract, archive_format, cache_dir)
#     256     try:
#     257       try:
# --> 258         urlretrieve(origin, fpath, dl_progress)
#     259       except urllib.error.HTTPError as e:
#     260         raise Exception(error_msg.format(origin, e.code, e.msg))
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     508         # accept a URL or a Request object
#     509         if isinstance(fullurl, str):
# --> 510             req = Request(fullurl, data)
#     511         else:
#     512             req = fullurl
#
# /usr/lib/python3.7/urllib/request.py in __init__(self, url, data, headers, origin_req_host, unverifiable, method)
#     326                  origin_req_host=None, unverifiable=False,
#     327                  method=None):
# --> 328         self.full_url = url
#     329         self.headers = {}
#     330         self.unredirected_hdrs = {}
#
# /usr/lib/python3.7/urllib/request.py in full_url(self, url)
#     352         self._full_url = unwrap(url)
#     353         self._full_url, self.fragment = splittag(self._full_url)
# --> 354         self._parse()
#     355
#     356     @full_url.deleter
#
# /usr/lib/python3.7/urllib/request.py in _parse(self)
#     381         self.type, rest = splittype(self._full_url)
#     382         if self.type is None:
# --> 383             raise ValueError("unknown url type: %r" % self.full_url)
#     384         self.host, self.selector = splithost(rest)
#     385         if self.host:
#
# ValueError: unknown url type: './content/content/MyDrive/rough'
